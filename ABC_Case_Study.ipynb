# %% [markdown]
# #**ABC Case Study**
# ABC is an American subscription video on-demand over-the-top streaming service owned and operated by ABC, Inc. The service primarily distributes films and television series produced by the media company of the same name from various genres, and it is available internationally in multiple languages.
#
# Analyze the data and generate insights that could help ABC in deciding which type of shows/movies to produce and how they can grow the business in different countries

# %%
#Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Getting the Data From CSV file
raw_data=pd.read_csv('abc.csv')
raw_data.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
raw_data.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
raw_data.shape
# Out:
# (8807, 12)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
raw_data.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
raw_data.duplicated().sum()
# Out:
# 0

# %%
raw_data.duplicated(subset=['show_id','title']).sum()
# Out:
# 0

# %% [markdown]
# **Data Exploration Insight**
#
# By Exploring and inspecting the dataset we have found following things:
#
# 1. No of Rows = 8807, cols = 12
#
# 2. 'date_added' Column is in string which needs attention
#
# 3. There are null or nan values
#
# 4. There are multiple comma separated values for single field in columns -
# director, cast, listed_in, country
#
# 5. There are no duplicate rows in the data and no duplicate titles.
#
# 6. show_id and title are unique ,so can be used as primary key.

# %%
new_data=raw_data.copy()

# %%
#converting the comma seprated values to list
new_data['cast']=new_data['cast'].str.split(',')
new_data['country']=new_data['country'].str.split(',')
new_data['listed_in']=new_data['listed_in'].str.split(',')
new_data['director']=new_data['director'].str.split(',')
new_data.head()
# Out:
#   show_id     type                  title           director  \
# 0      s1    Movie   Dick Johnson Is Dead  [Kirsten Johnson]
# 1      s2  TV Show          Blood & Water                NaN
# 2      s3  TV Show              Ganglands  [Julien Leclercq]
# 3      s4  TV Show  Jailbirds New Orleans                NaN
# 4      s5  TV Show           Kota Factory                NaN
#
#                                                 cast          country  \
# 0                                                NaN  [United States]
# 1  [Ama Qamata,  Khosi Ngema,  Gail Mabalane,  Th...   [South Africa]
# 2  [Sami Bouajila,  Tracy Gotoas,  Samuel Jouy,  ...              NaN
# 3                                                NaN              NaN
# 4  [Mayur More,  Jitendra Kumar,  Ranjan Raj,  Al...          [India]
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#Unnesting the columns
new_data=new_data.explode('cast')
new_data=new_data.explode('country')
new_data=new_data.explode('listed_in')
new_data=new_data.explode('director')

# %%
#removing unwanted spaces
new_data['country']=new_data['country'].str.strip()
new_data['director']=new_data['director'].str.strip()
new_data['cast']=new_data['cast'].str.strip()
new_data['listed_in']=new_data['listed_in'].str.strip()

# %%
new_data=new_data.reset_index(drop=True)
new_data.head()
# Out:
#   show_id     type                 title         director         cast  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson          NaN
# 1      s2  TV Show         Blood & Water              NaN   Ama Qamata
# 2      s2  TV Show         Blood & Water              NaN   Ama Qamata
# 3      s2  TV Show         Blood & Water              NaN   Ama Qamata
# 4      s2  TV Show         Blood & Water              NaN  Khosi Ngema
#
#          country          date_added  release_year rating   duration  \
# 0  United States  September 25, 2021          2020  PG-13     90 min
# 1   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 2   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 3   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 4   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
#
#                 listed_in                                        description
# ...

# %%
new_data.shape
# Out:
# (202065, 12)

# %%
new_data.duplicated().sum()
# Out:
# 55

# %%
new_data.drop_duplicates(inplace=True)

# %%
new_data.duplicated().sum()
# Out:
# 0

# %%
#filling NaN or empty values
new_data['director'].fillna('unknown_director',inplace=True)
new_data['cast'].fillna('unknown_actor',inplace=True)
new_data['country'].fillna('unknown_country',inplace=True)
new_data['rating'].fillna('unknown_rating',inplace=True)
new_data['date_added'].fillna('2022-01-01',inplace=True)
new_data['duration'].fillna('unknown_duration',inplace=True)

# %%
new_data['date_added']=pd.to_datetime(new_data['date_added'])

# %%
#Extracting week no from every date and then creating new column
def applyweekno(g):
  if g>=1 and g<=8:
    weekno=1
  elif g>8 and g<=15:
    weekno=2
  elif g>15 and g<22:
    weekno=3
  else:
    weekno=4
  return weekno

new_data['week_of_month']=new_data['date_added'].dt.day.apply(applyweekno)

# %%
new_data['month_added']=new_data['date_added'].dt.month_name()

# %%
new_data['difference_in_years']=np.abs(new_data['date_added'].dt.year-new_data['release_year'])

# %%
new_data.duplicated().sum()
# Out:
# 0

# %%
new_data.isna().sum()
# Out:
# show_id                0
# type                   0
# title                  0
# director               0
# cast                   0
# country                0
# date_added             0
# release_year           0
# rating                 0
# duration               0
# listed_in              0
# description            0
# week_of_month          0
# month_added            0
# difference_in_years    0
# dtype: int64

# %%
movies_data=new_data[new_data['type']=='Movie']
tv_data=new_data[new_data['type']=='TV Show']

# %% [markdown]
# **Q1. Find the counts of each categorical variable both using graphical and non-
# graphical analysis**

# %%
type_counts=new_data.groupby('type').aggregate({'title':'nunique'}).sort_values(by='title',ascending=False).reset_index()
type_counts.rename(columns={'title':'count'},inplace=True)

rating_counts=new_data.groupby('rating').aggregate({'title':'nunique'}).sort_values(by='title',ascending=False).reset_index()
rating_counts.rename(columns={'title':'count'},inplace=True)

listed_in_counts=new_data.groupby('listed_in').aggregate({'title':'nunique'}).sort_values(by='title',ascending=False).reset_index()
listed_in_counts.rename(columns={'title':'count'},inplace=True)

# %%
print(type_counts,rating_counts,listed_in_counts,sep='\n\n\n')
# Out:
#       type  count
# 0    Movie   6131
# 1  TV Show   2676
#
#
#             rating  count
# 0            TV-MA   3207
# 1            TV-14   2160
# 2            TV-PG    863
# 3                R    799
# 4            PG-13    490
# 5            TV-Y7    334
# 6             TV-Y    307
# 7               PG    287
# 8             TV-G    220
# 9               NR     80
# 10               G     41
# 11        TV-Y7-FV      6
# 12  unknown_rating      4
# 13           NC-17      3
# 14              UR      3
# 15          74 min      1
# 16          84 min      1
# 17          66 min      1
#
#
#                        listed_in  count
# 0           International Movies   2752
# 1                         Dramas   2427
# 2                       Comedies   1674
# 3         International TV Shows   1351
# 4                  Documentaries    869
# 5             Action & Adventure    859
# 6                      TV Dramas    763
# 7             Independent Movies    756
# ...

# %%
plt.figure(figsize=(8,20))
plt.subplot(6,1,1)
sns.barplot(data=type_counts,x='type',y='count')
plt.subplot(6,1,3)
plt.xticks(rotation=90)
sns.barplot(data=rating_counts,x='rating',y='count')
plt.subplot(6,1,5)
plt.xticks(rotation=90)
sns.barplot(data=listed_in_counts.head(10),x='listed_in',y='count')
# Out:
# <Axes: xlabel='listed_in', ylabel='count'>

# %% [markdown]
# **Business Insight - 1:**
#
# By analyzing above data we got to know that:
#
# 1. There are more Movies on the platform as compared to TV Shows.
#
# 2. TV-MA and TV-14 ratings are more popular.
#
# 3. Most popular genres are International Movies, Dramas, Comedies.

# %% [markdown]
# **Q2. Find the number of movies produced in each country and pick the top 10
# countries.**

# %%
movies_by_country = movies_data.groupby(by='country').aggregate({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False).reset_index(drop=True)
movies_by_country.rename(columns={'title':'movies_count'},inplace=True)

top10_movies=movies_by_country.head(10)
bottom10_movies=movies_by_country.tail(10)
top10_movies
# Out:
#            country  movies_count
# 0    United States          2752
# 1            India           962
# 2   United Kingdom           534
# 3  unknown_country           440
# 4           Canada           319
# 5           France           303
# 6          Germany           182
# 7            Spain           171
# 8            Japan           119
# 9            China           114

# %%
plt.xticks(rotation=90)
sns.barplot(data=top10_movies,x='country',y='movies_count')
# Out:
# <Axes: xlabel='country', ylabel='movies_count'>

# %% [markdown]
# **Business Insight - 2:**
#
# By analyzing above data we got to know that:
#
# 1. Most movies are released in United States, India, United Kingdom

# %% [markdown]
# **Find the number of TV Shows produced in each country and pick the top 10
# countries**

# %%
tv_by_country = tv_data.groupby('country').aggregate({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False).reset_index(drop=True)
tv_by_country.rename(columns={'title':'tv_show_count'},inplace=True)

top10_tv = tv_by_country.head(10)
top10_tv
# Out:
#            country  tv_show_count
# 0    United States            938
# 1  unknown_country            391
# 2   United Kingdom            272
# 3            Japan            199
# 4      South Korea            170
# 5           Canada            126
# 6           France             90
# 7            India             84
# 8           Taiwan             70
# 9        Australia             66

# %%
plt.xticks(rotation=90)
sns.barplot(data=top10_tv,x='country',y='tv_show_count')
# Out:
# <Axes: xlabel='country', ylabel='tv_show_count'>

# %% [markdown]
# **Business Insight - 3**
#
# By analyzing above data we got to know that:
#
# 1. Most **TV Shows** are released in United States, United Kindom, Japan

# %% [markdown]
# **Q3. Find which is the best week to release the movie.**

# %%
weekgrp = movies_data.groupby('week_of_month').aggregate({'title':'nunique'}).sort_values(by='title',ascending=False).reset_index().head(10)
weekgrp
# Out:
#    week_of_month  title
# 0              1   2713
# 1              4   1333
# 2              2   1151
# 3              3    934

# %%
print(plt.pie(weekgrp['title'],labels=weekgrp['week_of_month'],autopct='%.0f%%'))
# Out:
# ([<matplotlib.patches.Wedge object at 0x7e8c959d8820>, <matplotlib.patches.Wedge object at 0x7e8c959d8700>, <matplotlib.patches.Wedge object at 0x7e8c959d9510>, <matplotlib.patches.Wedge object at 0x7e8c959d9ba0>], [Text(0.19760880580497814, 1.0821047822962113, '1'), Text(-1.0435364513320389, -0.34789606887881824, '4'), Text(0.026207352288148054, -1.0996877623607735, '2'), Text(0.9764086574705484, -0.5065828003560341, '3')], [Text(0.1077866213481699, 0.5902389721615697, '44%'), Text(-0.5692017007265666, -0.18976149211571902, '22%'), Text(0.014294919429898937, -0.5998296885604218, '19%'), Text(0.5325865404384809, -0.27631789110329125, '15%')])

# %% [markdown]
# **Business Insight - 4**:
#
# By analyzing above data we got to know that:
#
# 1. Most Movies are added in first week of the month
# 2. Very few movies are added in third week of the month.

# %% [markdown]
# **Q4. Find which is the best month to release the Tv-show or the movie.**

# %%
movie_month= movies_data.groupby(by='month_added').aggregate({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False).reset_index(drop=True)
movie_month.rename(columns={'title':'movie_count'},inplace=True)
movie_month
# Out:
#    month_added  movie_count
# 0         July          565
# 1        April          550
# 2     December          547
# 3      January          546
# 4      October          545
# 5        March          529
# 6       August          519
# 7    September          519
# 8     November          498
# 9         June          492
# 10         May          439
# 11    February          382

# %%
tv_month = tv_data.groupby(by='month_added').aggregate({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False).reset_index(drop=True)
tv_month.rename(columns={'title':'tv_count'},inplace=True)
tv_month
# Out:
#    month_added  tv_count
# 0     December       266
# 1         July       262
# 2    September       251
# 3       August       236
# 4         June       236
# 5      October       215
# 6        April       214
# 7        March       213
# 8     November       207
# 9      January       202
# 10         May       193
# 11    February       181

# %%
tv_movie_count = movie_month.merge(tv_month,on='month_added',how='outer').sort_values(by=['movie_count','tv_count'],ascending=False).reset_index(drop=True)
tv_movie_count_grp = tv_movie_count.melt(id_vars=['month_added'],value_vars=['movie_count','tv_count'],var_name='type',value_name='count')
tv_movie_count_grp
# Out:
#    month_added         type  count
# 0         July  movie_count    565
# 1        April  movie_count    550
# 2     December  movie_count    547
# 3      January  movie_count    546
# 4      October  movie_count    545
# 5        March  movie_count    529
# 6    September  movie_count    519
# 7       August  movie_count    519
# 8     November  movie_count    498
# 9         June  movie_count    492
# 10         May  movie_count    439
# 11    February  movie_count    382
# 12        July     tv_count    262
# 13       April     tv_count    214
# 14    December     tv_count    266
# 15     January     tv_count    202
# 16     October     tv_count    215
# 17       March     tv_count    213
# 18   September     tv_count    251
# 19      August     tv_count    236
# 20    November     tv_count    207
# 21        June     tv_count    236
# 22         May     tv_count    193
# 23    February     tv_count    181

# %%
plt.xticks(rotation=90)
sns.barplot(data=tv_movie_count_grp,x='month_added',y='count',hue='type')
# Out:
# <Axes: xlabel='month_added', ylabel='count'>

# %% [markdown]
# **Business Insight - 5:**
#
# By analyzing above data we got to know that:
#
# 1. Most Movies and TV shows are released in july, april, december.
# 2. Very Few Movies and TV shows are released in month of may, february

# %% [markdown]
# **Q5. Identify the top 10 directors who have appeared in most movies.**

# %%
movie_directors_count=movies_data.groupby('director').aggregate({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False).reset_index(drop=True)
movie_directors_count.rename(columns={'title':'movie_count'},inplace=True)

top10_movie_directors=movie_directors_count.head(10)
top10_movie_directors
# Out:
#               director  movie_count
# 0     unknown_director          188
# 1        Rajiv Chilaka           22
# 2            Jan Suter           21
# 3          Raúl Campos           19
# 4          Suhas Kadav           16
# 5         Marcus Raboy           15
# 6            Jay Karas           15
# 7  Cathy Garcia-Molina           13
# 8      Youssef Chahine           12
# 9      Martin Scorsese           12

# %% [markdown]
# **Q6. Identify the top 10 actors who have appeared in most movies.**

# %%
movie_actors_count = movies_data.groupby('cast').aggregate({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False).reset_index(drop=True).head(10)
movie_actors_count.rename(columns={'title':'movie_count','cast':'actor'},inplace=True)

top10_movie_actors = movie_actors_count.head(10)
top10_movie_actors
# Out:
#               actor  movie_count
# 0     unknown_actor          475
# 1       Anupam Kher           42
# 2    Shah Rukh Khan           35
# 3  Naseeruddin Shah           32
# 4           Om Puri           30
# 5      Akshay Kumar           30
# 6  Amitabh Bachchan           28
# 7     Julie Tejwani           28
# 8      Paresh Rawal           28
# 9       Boman Irani           27

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
plt.xticks(rotation=90)
sns.barplot(data=top10_movie_actors,x='actor',y='movie_count')
plt.subplot(1,3,3)
plt.xticks(rotation=90)
sns.barplot(data=top10_movie_directors,x='director',y='movie_count')
# Out:
# <Axes: xlabel='director', ylabel='movie_count'>

# %% [markdown]
# **Business Insight - 6:**
#
# By analyzing above data we got to know that:
#
# 1. Anupam Kher, Shahrukh Khan are top actors as they have worked in most films.
# 2. Rajiv Chilaka, Jan Suter are top directors as they have directed lots of movies.

# %% [markdown]
# **Q7. Identify the top 10 directors who have appeared in most TV Shows.**

# %%
tv_directors_count=tv_data.groupby('director').aggregate({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False).reset_index(drop=True)
tv_directors_count.rename(columns={'title':'tv_count'},inplace=True)

top10_tv_directors=tv_directors_count.head(10)
top10_tv_directors
# Out:
#                 director  tv_count
# 0       unknown_director      2446
# 1              Ken Burns         3
# 2    Alastair Fothergill         3
# 3             Jung-ah Im         2
# 4          Joe Berlinger         2
# 5            Hsu Fu-chun         2
# 6            Stan Lathan         2
# 7  Gautham Vasudev Menon         2
# 8            Lynn Novick         2
# 9            Shin Won-ho         2

# %% [markdown]
# **Q8. Identify the top 10 actors who have appeared in most TV Shows.**

# %%
tv_actors_count = tv_data.groupby('cast').aggregate({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False).reset_index(drop=True)
tv_actors_count.rename(columns={'title':'tv_count','cast':'actor'},inplace=True)

top10_tv_actors = tv_actors_count.head(10)
top10_tv_actors
# Out:
#                 actor  tv_count
# 0       unknown_actor       350
# 1    Takahiro Sakurai        25
# 2           Yuki Kaji        19
# 3           Ai Kayano        17
# 4      Junichi Suwabe        17
# 5         Daisuke Ono        17
# 6     Yuichi Nakamura        16
# 7    Yoshimasa Hosoya        15
# 8        Jun Fukuyama        15
# 9  David Attenborough        14

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
plt.xticks(rotation=90)
sns.barplot(data=top10_tv_actors,x='actor',y='tv_count')
plt.subplot(1,3,3)
plt.xticks(rotation=90)
sns.barplot(data=top10_tv_directors,x='director',y='tv_count')
# Out:
# <Axes: xlabel='director', ylabel='tv_count'>

# %% [markdown]
# **Business Insight - 7**:
# 1. Takahiro Sakurai, Yuki Kahi are top actors as they have worked in most TV Shows.
# 2. Ken Burns, Alastair Fothergill are top directors as they have directed lots of Shows.

# %% [markdown]
# **Q9. Which genre movies are more popular or produced more**

# %%
genre_counts=new_data.groupby('listed_in').aggregate({'title':'nunique'}).reset_index().sort_values(by='title',ascending=False).reset_index(drop=True)
genre_counts.rename(columns={'title':'genre_count','listed_in':'genre'},inplace=True)

top10_genre=genre_counts.head(10)
top10_genre
# Out:
#                       genre  genre_count
# 0      International Movies         2752
# 1                    Dramas         2427
# 2                  Comedies         1674
# 3    International TV Shows         1351
# 4             Documentaries          869
# 5        Action & Adventure          859
# 6                 TV Dramas          763
# 7        Independent Movies          756
# 8  Children & Family Movies          641
# 9           Romantic Movies          616

# %%
genre_counts_li=[]
for i in genre_counts.values:
  for j in range(i[1]):
    s=i[0].lower()
    genre_counts_li.append(s)

# %%
import wordcloud as wd

genre_word_string = " ".join(genre_counts_li)
plt.figure(figsize=(15,15))
wc = wd.WordCloud(max_font_size= 200,  width=2000, height=1000)
wc.generate(genre_word_string)
plt.title('Genre Word Cloud')
plt.axis('off')
plt.imshow(wc)

# %% [markdown]
# **Business Insight - 8:**
#
# By analyzing above data we got to know that:
#
# 1. international movies, dramas, comedies, international tv shows are most  popular genre.

# %% [markdown]
# **Q10. Find After how many days the movie will be added to ABC after the release of the movie.**

# %%
diff_counts=movies_data.groupby('difference_in_years').aggregate({'title':'nunique'}).reset_index()
diff_counts.rename(columns={'title':'diff_count'},inplace=True)

top10_diff_counts=diff_counts.sort_values(by='diff_count',ascending=False).reset_index(drop=True).head(10)
top10_diff_counts
# Out:
#    difference_in_years  diff_count
# 0                    0        1862
# 1                    1        1180
# 2                    2         491
# 3                    3         347
# 4                    4         273
# 5                    5         191
# 6                    6         181
# 7                    8         147
# 8                    7         139
# 9                    9         128

# %%
sns.barplot(data=top10_diff_counts,x='difference_in_years',y='diff_count')
# Out:
# <Axes: xlabel='difference_in_years', ylabel='diff_count'>

# %% [markdown]
# **Business Insight - 9:**
#
# By analyzing above data we got to know that:
#
# 1. Most Movies are added within the same year or within next two years

# %% [markdown]
# **Q11. How has the number of movies released per year changed over the last 20-30 years.**

# %%
movie_by_year=movies_data.groupby('release_year').aggregate({'title':'nunique'}).reset_index()
movie_by_year.rename(columns={'title':'movie_count'},inplace=True)

top30_years=movie_by_year.sort_values(by='release_year',ascending=False).reset_index(drop=True).head(30)
top30_years.head(10)
# Out:
#    release_year  movie_count
# 0          2021          277
# 1          2020          517
# 2          2019          633
# 3          2018          767
# 4          2017          767
# 5          2016          658
# 6          2015          398
# 7          2014          264
# 8          2013          225
# 9          2012          173

# %%
plt.xticks(rotation=90)
sns.barplot(data=top30_years,x='release_year',y='movie_count')
# Out:
# <Axes: xlabel='release_year', ylabel='movie_count'>

# %% [markdown]
# **Business Insight - 10:**
#
# By analyzing above data we got to know that:
#
# 1. We can see from the above data that there has been increase in count of movies though we can clearly see that there is decrease in count from 2019.

# %% [markdown]
# # **Recommendations**

# %% [markdown]
# **Recommendations based on Business Insight - 1:**
# 1. Focus on producing more movies to cater to the larger audience base on the platform.
# 2. Develop content with TV-MA and TV-14 ratings as they are more popular among viewers.
# 3. Allocate resources for creating and acquiring content in the International Movies, Dramas, and Comedies genres to tap into their popularity.
#
# **Recommendations based on Business Insight - 2:**
# 1. Collaborate with production companies and filmmakers in the United States, India, and the United Kingdom to create movies that cater to the preferences of these regions.
#
# **Recommendations based on Business Insight - 3:**
# 1. Build partnerships with TV show creators and producers in the United States, United Kingdom, and Japan to secure a steady stream of engaging TV show content.
# 2. Plan marketing and promotion strategies tailored to these specific regions to boost viewership.
#
# **Recommendations based on Business Insight - 4:**
# 1. Optimize content release schedules to focus on the first week of the month for movie releases to capitalize on higher viewership during this time.
# 2. Consider experimenting with promotional offers or exclusives during the third week of the month to encourage viewer engagement.
#
# **Recommendations based on Business Insight - 5:**
# 1. Plan major content releases for the months of July, April, and December to coincide with the periods of higher viewership.
# 2. Utilize the months of May and February for targeted promotions and engagement strategies to overcome the lower release activity.
#
# **Recommendations based on Business Insight - 6 and 7:**
# 1. Leverage the popularity of actors like Anupam Kher, Shahrukh Khan, Takahiro Sakurai, and Yuki Kaji by featuring their work prominently in marketing campaigns.
# 2. Collaborate with top directors Rajiv Chilaka, Jan Suter, Ken Burns, and Alastair Fothergill to create high-quality content that resonates with viewers.
#
# **Recommendations based on Business Insight - 8:**
# 1. Focus on producing a mix of international movies, dramas, comedies, and international TV shows to cater to the most popular genres among viewers.
#
# **Recommendations based on Business Insight - 9:**
# 1. Prioritize the acquisition or production of movies that can be released within the same year or the next two years to meet viewer expectations for timely content.
#
# **Recommendations based on Business Insight - 10:**
# 1. Investigate the reasons behind the increase in movie count and the subsequent decrease from 2019 to understand changing viewer behaviors and preferences.
# 2. Continuously monitor and analyze viewer trends to adapt your content strategy and ensure sustainable growth.
#
# Regularly analyzing new data and adjusting your strategies accordingly will be crucial to your long-term success.
